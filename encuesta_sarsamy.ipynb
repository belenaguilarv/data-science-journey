# %%
import io
import pandas as pd
import csv

# %%
path = 'datasets/2025.2 - Sysarmy - Encuesta de remuneración salarial Argentina - Sysarmy - sueldos - 2025.02CLEAN.csv'
df = pd.read_csv(path)
df
# Out:
#      Para analizar los resultados podés bajar el .csv (Archivo > Descargar)        \n        \nRecordá calificar a la empresa donde estás trabajando en www.openqube.io\n\nEsta obra está bajo una Licencia Creative Commons Atribución-NoComercial-CompartirIgual 4.0 Internacional.  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3752                                       Buenos Aires
# 3753                                       Buenos Aires
# 3754                    Ciudad Autónoma de Buenos Aires
# 3755                    Ciudad Autónoma de Buenos Aires
# 3756                                           Santa Fe
#
#      Unnamed: 1                                         Unnamed: 2  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ...         ...                                                ...
# 3752  Part-Time                          Staff (planta permanente)
# 3753  Full-Time  Tercerizado (trabajo a través de consultora o ...
# 3754  Full-Time                          Staff (planta permanente)
# 3755  Full-Time                          Staff (planta permanente)
# 3756  Full-Time        Participación societaria en una cooperativa
#
#       Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6             Unnamed: 7  \
# 0            NaN         NaN        NaN        NaN                    NaN
# 1            NaN         NaN        NaN        NaN                    NaN
# 2            NaN         NaN        NaN        NaN                    NaN
# 3            NaN         NaN        NaN        NaN                    NaN
# 4            NaN         NaN        NaN        NaN                    NaN
# ...          ...         ...        ...        ...                    ...
# 3752     4500000     4250000        NaN        NaN              Un sueldo
# 3753     1400000     1200000        NaN        NaN                     No
# 3754     3700000     3200000        NaN        NaN                     No
# 3755     3200000     2567000        NaN        NaN              Un sueldo
# 3756  1310771.18  1117423.86        NaN        NaN  De uno a tres sueldos
#
#                          Unnamed: 8 Unnamed: 9  ...        Unnamed: 46  \
# 0                               NaN        NaN  ...                NaN
# 1                               NaN        NaN  ...                NaN
# 2                               NaN        NaN  ...                NaN
# 3                               NaN        NaN  ...                NaN
# 4                               NaN        NaN  ...                NaN
# ...                             ...        ...  ...                ...
# 3752         Performance individual        Uno  ...                NaN
# 3753                 No recibo bono        Uno  ...                NaN
# 3754                 No recibo bono        Dos  ...                NaN
# 3755          Mix de las anteriores       Tres  ...                NaN
# 3756  Votado por decisión colectiva        Uno  ...  Terminar encuesta
#
#      Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52  \
# 0            NaN         NaN         NaN         NaN         NaN         NaN
# 1            NaN         NaN         NaN         NaN         NaN         NaN
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4            NaN         NaN         NaN         NaN         NaN         NaN
# ...          ...         ...         ...         ...         ...         ...
# 3752         NaN         NaN         NaN          27  Hombre Cis          No
# 3753         NaN         NaN         NaN          25  Hombre Cis          Sí
# 3754         NaN         NaN         NaN          43  Hombre Cis          Sí
# 3755         NaN         NaN         NaN          24  Hombre Cis          Sí
# 3756         NaN         NaN         NaN          33  Hombre Cis          No
#
#      Unnamed: 53  Unnamed: 54 Unnamed: 55
# 0            NaN          NaN         NaN
# 1            NaN          NaN         NaN
# 2            NaN          NaN         NaN
# 3            NaN          NaN         NaN
# 4            NaN          NaN         NaN
# ...          ...          ...         ...
# 3752       FALSE       Senior     4500000
# 3753       FALSE  Semi-Senior     1400000
# 3754       FALSE       Senior     3700000
# 3755       FALSE  Semi-Senior     3200000
# 3756       FALSE  Semi-Senior  1310771.18
#
# [3757 rows x 56 columns]

# %% [markdown]
# Como vemos, no estamos obteniendo los datos de forma correcta ya que el archivo.csv tiene las primerlas 9 filas con texto que no es de interes para este análisis y termina siendo perjudicial al momento de leer el dataset. Lo mas conveniente es hacer una lectura desde la fila que contiene los encabezados

# %%
df_fixed = pd.read_csv(path, skiprows=range(8), header=1)

# %%
df_fixed
# Out:
#                donde_estas_trabajando dedicacion  \
# 0     Ciudad Autónoma de Buenos Aires  Full-Time
# 1                        Buenos Aires  Full-Time
# 2     Ciudad Autónoma de Buenos Aires  Full-Time
# 3                             Mendoza  Full-Time
# 4                        Buenos Aires  Full-Time
# ...                               ...        ...
# 3743                     Buenos Aires  Part-Time
# 3744                     Buenos Aires  Full-Time
# 3745  Ciudad Autónoma de Buenos Aires  Full-Time
# 3746  Ciudad Autónoma de Buenos Aires  Full-Time
# 3747                         Santa Fe  Full-Time
#
#                                        tipo_de_contrato  \
# 0                             Staff (planta permanente)
# 1     Tercerizado (trabajo a través de consultora o ...
# 2                             Staff (planta permanente)
# 3                                            Contractor
# 4                             Staff (planta permanente)
# ...                                                 ...
# 3743                          Staff (planta permanente)
# 3744  Tercerizado (trabajo a través de consultora o ...
# 3745                          Staff (planta permanente)
# 3746                          Staff (planta permanente)
# 3747        Participación societaria en una cooperativa
#
#       ultimo_salario_mensual_o_retiro_bruto_en_pesos_argentinos  \
# 0                                            2511178.00
# 1                                            2140000.00
# 2                                            3000000.00
# 3                                            4000000.00
# 4                                            1300000.00
# ...                                                 ...
# 3743                                         4500000.00
# 3744                                         1400000.00
# 3745                                         3700000.00
# 3746                                         3200000.00
# 3747                                         1310771.18
#
#       ultimo_salario_mensual_o_retiro_neto_en_pesos_argentinos  \
# 0                                            2085000.00
# 1                                            2140000.00
# 2                                             310000.00
# 3                                            4000000.00
# 4                                            1000000.00
# ...                                                 ...
# 3743                                         4250000.00
# 3744                                         1200000.00
# 3745                                         3200000.00
# 3746                                         2567000.00
# 3747                                         1117423.86
#
#                         pagos_en_dolares  \
# 0     Cobro parte del salario en dólares
# 1       Cobro todo el salario en dólares
# 2     Cobro parte del salario en dólares
# 3       Cobro todo el salario en dólares
# 4     Cobro parte del salario en dólares
# ...                                  ...
# 3743                                 NaN
# 3744                                 NaN
# 3745                                 NaN
# 3746                                 NaN
# 3747                                 NaN
#
#      si_tu_sueldo_esta_dolarizado_cual_fue_el_ultimo_valor_del_dolar_que_tomaron  \
# 0                          Dólar oficial al día de oago
# 1                                                  1160
# 2                                                   NaN
# 3                                                  1185
# 4                                                   NaN
# ...                                                 ...
# 3743                                                NaN
# 3744                                                NaN
# 3745                                                NaN
# 3746                                                NaN
# 3747                                                NaN
#
#      recibis_algun_tipo_de_bono       a_que_esta_atado_el_bono  \
# 0                            No                 No recibo bono
# 1                            No                 No recibo bono
# 2                    3+ sueldos     Performance de la compañía
# 3                            No                 No recibo bono
# 4         De uno a tres sueldos          Mix de las anteriores
# ...                         ...                            ...
# 3743                  Un sueldo         Performance individual
# 3744                         No                 No recibo bono
# 3745                         No                 No recibo bono
# 3746                  Un sueldo          Mix de las anteriores
# 3747      De uno a tres sueldos  Votado por decisión colectiva
#
#      tuviste_actualizaciones_de_tus_ingresos_laborales_durante_el_ultimo_semestre  \
# 0                                                   Uno
# 1                                                   Uno
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 3743                                                Uno
# 3744                                                Uno
# 3745                                                Dos
# 3746                                               Tres
# 3747                                                Uno
#
#       ...  salir_o_seguir_contestando_sobre_las_guardias1 tenes_guardias  \
# 0     ...                                             NaN            NaN
# 1     ...                                             NaN            NaN
# 2     ...                                             NaN            NaN
# 3     ...                               Terminar encuesta             No
# 4     ...                                             NaN            NaN
# ...   ...                                             ...            ...
# 3743  ...                                             NaN            NaN
# 3744  ...                                             NaN            NaN
# 3745  ...                                             NaN            NaN
# 3746  ...                                             NaN            NaN
# 3747  ...                               Terminar encuesta            NaN
#
#       cuanto_cobras_por_guardia  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           0.0
# 4                           NaN
# ...                         ...
# 3743                        NaN
# 3744                        NaN
# 3745                        NaN
# 3746                        NaN
# 3747                        NaN
#
#      aclara_el_numero_que_ingresaste_en_el_campo_anterior  tengo_edad  \
# 0                                                   NaN            43
# 1                                                   NaN            59
# 2                                                   NaN            39
# 3                                                  Neto            37
# 4                                                   NaN            35
# ...                                                 ...           ...
# 3743                                                NaN            27
# 3744                                                NaN            25
# 3745                                                NaN            43
# 3746                                                NaN            24
# 3747                                                NaN            33
#
#           genero habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 0      Mujer Cis                                                 No
# 1      Mujer Cis                                                 Sí
# 2     Hombre Cis                                                 Sí
# 3     Hombre Cis                                                 Sí
# 4     Hombre Cis                                                 Sí
# ...          ...                                                ...
# 3743  Hombre Cis                                                 No
# 3744  Hombre Cis                                                 Sí
# 3745  Hombre Cis                                                 Sí
# 3746  Hombre Cis                                                 Sí
# 3747  Hombre Cis                                                 No
#
#      sueldo_dolarizado    seniority        _sal
# 0                 True  Semi-Senior  2511178.00
# 1                 True       Senior  2140000.00
# 2                 True  Semi-Senior  3000000.00
# 3                 True       Senior  4000000.00
# 4                 True       Senior  1300000.00
# ...                ...          ...         ...
# 3743             False       Senior  4500000.00
# 3744             False  Semi-Senior  1400000.00
# 3745             False       Senior  3700000.00
# 3746             False  Semi-Senior  3200000.00
# 3747             False  Semi-Senior  1310771.18
#
# [3748 rows x 56 columns]

# %% [markdown]
# Vamos a renombrar las columnas para mayor facilidad al momento de realizar el análisis del DataFrame. Crearemos categorías que nos ayuden a agrupar los encabezados

# %%
df_fixed.columns
# Out:
# Index(['donde_estas_trabajando', 'dedicacion', 'tipo_de_contrato',
#        'ultimo_salario_mensual_o_retiro_bruto_en_pesos_argentinos',
#        'ultimo_salario_mensual_o_retiro_neto_en_pesos_argentinos',
#        'pagos_en_dolares',
#        'si_tu_sueldo_esta_dolarizado_cual_fue_el_ultimo_valor_del_dolar_que_tomaron',
#        'recibis_algun_tipo_de_bono', 'a_que_esta_atado_el_bono',
#        'tuviste_actualizaciones_de_tus_ingresos_laborales_durante_el_ultimo_semestre',
#        'de_que_fue_el_ajuste_total_acumulado',
#        'en_que_mes_fue_el_ultimo_ajuste',
#        'como_consideras_que_estan_tus_ingresos_laborales_comparados_con_el_semestre_anterior',
#        'contas_con_beneficios_adicionales',
#        'que_tan_conforme_estas_con_tus_ingresos_laborales',
#        'estas_buscando_trabajo', 'pluriempleo', 'trabajo_de',
#        'anos_de_experiencia', 'antiguedad_en_la_empresa_actual',
#        'anos_en_el_puesto_actual', 'cuantas_personas_tenes_a_cargo',
#        'plataformas_que_utilizas_en_tu_puesto_actual',
#        'lenguajes_de_programacion_o_tecnologias_que_utilices_en_tu_puesto_actual',
#        'frameworksherramientas_y_librerias_que_utilices_en_tu_puesto_actual',
#        'bases_de_datos', 'qa_testing',
#        'cantidad_de_personas_en_tu_organizacion', 'modalidad_de_trabajo',
#        'si_trabajas_bajo_un_esquema_hibrido_cuantos_dias_a_la_semana_vas_a_la_oficina',
#        'en_los_ultimos_6_mesesse_aplico_alguna_politica_de_ajustes_salariales',
#        'en_los_ultimos_6_meseshubo_reduccion_de_personal',
#        'la_recomendas_como_un_buen_lugar_para_trabajar',
#        'que_tanto_estas_usando_copilotchatgpt_u_otras_herramientas_de_ia_para_tu_trabajo',
#        'vibe_coding', 'salir_o_seguir_contestando', 'maximo_nivel_de_estudios',
#        'estado', 'carrera', 'institucion_educativa',
#        'salir_o_seguir_contestando_sobre_las_guardias',
#        'cual_es_la_cantidad_maxima_de_entrevistas_que_consideras_aceptable_en_un_proceso_de_seleccion',
#        'cual_es_la_combinacion_de_entrevistas_que_consideras_mejor_en_tu_experiencia_como_candidatoa',
#        'desafios_tecnicoscomo_los_preferiselegi_todas_las_opciones_que_consideres',
#        'cuantas_horas_te_parecen_correctas_dedicarle_a_un_desafio_tecnico_asincronico',
#        'cual_de_las_siguientes_frases_representa_mejor_tu_opinion_acerca_de_los_procesos_de_seleccion',
#        'salir_o_seguir_contestando_sobre_las_guardias1', 'tenes_guardias',
#        'cuanto_cobras_por_guardia',
#        'aclara_el_numero_que_ingresaste_en_el_campo_anterior', 'tengo_edad',
#        'genero', 'habias_respondido_nuestra_encuesta_en_ediciones_anteriores',
#        'sueldo_dolarizado', 'seniority', '_sal'],
#       dtype='object')

# %%
new_columns = {
  'profile': {
      'genero': 'gender',
      'tengo_edad': 'age',
      'anos_de_experiencia': 'years_experience',
      'maximo_nivel_de_estudios': 'studies_level',
      'estado': 'studies_level_state',
      'carrera': 'career',
      'institucion_educativa': 'university',
      'habias_respondido_nuestra_encuesta_en_ediciones_anteriores': 'answered_previous_editions'
  },

  'work' : {
      'donde_estas_trabajando': 'province',
      'antiguedad_en_la_empresa_actual': 'years_in_company',
      'anos_en_el_puesto_actual': 'years_in_current_position',
      'cuantas_personas_tenes_a_cargo': 'people_in_charge_of',
      'tenes_guardias': 'on_call_duty',
      'modalidad_de_trabajo':'work_modality',
      'tipo_de_contrato':'contract_type',
      'dedicacion': 'dedication',
      'estas_buscando_trabajo': 'looking_for_job',
      'pluriempleo': 'multiple_jobs',
      'seniority': 'seniority',
      'vibe_coding': 'vibe_coding'
  },

  'tools': {
      'plataformas_que_utilizas_en_tu_puesto_actual': 'platform',
      'lenguajes_de_programacion_o_tecnologias_que_utilices_en_tu_puesto_actual': 'programming_languages',
      'frameworksherramientas_y_librerias_que_utilices_en_tu_puesto_actual': 'frameworks',
      'bases_de_datos': 'data_bases',
      'qa_testing': 'qa_testing',
      'que_tanto_estas_usando_copilotchatgpt_u_otras_herramientas_de_ia_para_tu_trabajo':'copilotchatgpt'
  },

  'salary': {
      'cuanto_cobras_por_guardia': 'on_call_duty_charge',
      'aclara_el_numero_que_ingresaste_en_el_campo_anterior': 'on_call_duty_charge_notes',
      'ultimo_salario_mensual_o_retiro_bruto_en_pesos_argentinos': 'monthly_BRUTO',
      'ultimo_salario_mensual_o_retiro_neto_en_pesos_argentinos': 'monthly_NETO',
      'pagos_en_dolares': 'in_usd',
      'si_tu_sueldo_esta_dolarizado_cual_fue_el_ultimo_valor_del_dolar_que_tomaron':'last_dollar_value',
      'como_consideras_que_estan_tus_ingresos_laborales_comparados_con_el_semestre_anterior': 'comparison_last_semester',
      'que_tan_conforme_estas_con_tus_ingresos_laborales': 'satisfaction',
      'recibis_algun_tipo_de_bono': 'has_bonus',
      'a_que_esta_atado_el_bono': 'bonus_tied_to',
      'tuviste_actualizaciones_de_tus_ingresos_laborales_durante_el_ultimo_semestre': 'inflation_adjustment_from_last_semester',
      'de_que_fue_el_ajuste_total_acumulado': 'percentage_inflation_adjustment',
      'en_que_mes_fue_el_ultimo_ajuste': 'month_last_inflation_adjustment',
      'contas_con_beneficios_adicionales': 'benefit',
      'sueldo_dolarizado': 'salary_dollarized',
      '_sal': 'salary_target'
  },

  'company' : {
      'cantidad_de_personas_en_tu_organizacion': 'employee_number',
      'trabajo_de': 'main_activity',
      'la_recomendas_como_un_buen_lugar_para_trabajar': 'recommended',
      'si_trabajas_bajo_un_esquema_hibrido_cuantos_dias_a_la_semana_vas_a_la_oficina':'days_in_the_office',
      'en_los_ultimos_6_mesesse_aplico_alguna_politica_de_ajustes_salariales': 'policy_salary_adjust_last6m',
      'en_los_ultimos_6_meseshubo_reduccion_de_personal': 'layoffs_last6m'
  },

  'hiring': {
      'cual_es_la_cantidad_maxima_de_entrevistas_que_consideras_aceptable_en_un_proceso_de_seleccion': 'hiring_max_interviews_ok',
      'cual_es_la_combinacion_de_entrevistas_que_consideras_mejor_en_tu_experiencia_como_candidatoa': 'hiring_interview_mix_preferred',
      'desafios_tecnicoscomo_los_preferiselegi_todas_las_opciones_que_consideres': 'hiring_tech_challenge_preference',
      'cuantas_horas_te_parecen_correctas_dedicarle_a_un_desafio_tecnico_asincronico': 'hiring_tech_challenge_hours',
      'cual_de_las_siguientes_frases_representa_mejor_tu_opinion_acerca_de_los_procesos_de_seleccion': 'hiring_opinion_statement'
  },

  # columnas de control de flujo
  'flow' : {
      'salir_o_seguir_contestando': 'flow_continue',
      'salir_o_seguir_contestando_sobre_las_guardias': 'flow_continue_oncall',
      'salir_o_seguir_contestando_sobre_las_guardias1': 'flow_continue_oncall_1'
  }
}

# %%
def replace_columns(df, new_columns):
    new_columns_names= {
        original_name: category + '_' + new_name
        for category, cols in new_columns.items()
        for original_name, new_name in cols.items()
    }
    return df.rename(columns=new_columns_names)

# %%
df_renamed = replace_columns(df_fixed, new_columns)
df_renamed
# Out:
#                         work_province work_dedication  \
# 0     Ciudad Autónoma de Buenos Aires       Full-Time
# 1                        Buenos Aires       Full-Time
# 2     Ciudad Autónoma de Buenos Aires       Full-Time
# 3                             Mendoza       Full-Time
# 4                        Buenos Aires       Full-Time
# ...                               ...             ...
# 3743                     Buenos Aires       Part-Time
# 3744                     Buenos Aires       Full-Time
# 3745  Ciudad Autónoma de Buenos Aires       Full-Time
# 3746  Ciudad Autónoma de Buenos Aires       Full-Time
# 3747                         Santa Fe       Full-Time
#
#                                      work_contract_type  salary_monthly_BRUTO  \
# 0                             Staff (planta permanente)            2511178.00
# 1     Tercerizado (trabajo a través de consultora o ...            2140000.00
# 2                             Staff (planta permanente)            3000000.00
# 3                                            Contractor            4000000.00
# 4                             Staff (planta permanente)            1300000.00
# ...                                                 ...                   ...
# 3743                          Staff (planta permanente)            4500000.00
# 3744  Tercerizado (trabajo a través de consultora o ...            1400000.00
# 3745                          Staff (planta permanente)            3700000.00
# 3746                          Staff (planta permanente)            3200000.00
# 3747        Participación societaria en una cooperativa            1310771.18
#
#       salary_monthly_NETO                       salary_in_usd  \
# 0              2085000.00  Cobro parte del salario en dólares
# 1              2140000.00    Cobro todo el salario en dólares
# 2               310000.00  Cobro parte del salario en dólares
# 3              4000000.00    Cobro todo el salario en dólares
# 4              1000000.00  Cobro parte del salario en dólares
# ...                   ...                                 ...
# 3743           4250000.00                                 NaN
# 3744           1200000.00                                 NaN
# 3745           3200000.00                                 NaN
# 3746           2567000.00                                 NaN
# 3747           1117423.86                                 NaN
#
#           salary_last_dollar_value       salary_has_bonus  \
# 0     Dólar oficial al día de oago                     No
# 1                             1160                     No
# 2                              NaN             3+ sueldos
# 3                             1185                     No
# 4                              NaN  De uno a tres sueldos
# ...                            ...                    ...
# 3743                           NaN              Un sueldo
# 3744                           NaN                     No
# 3745                           NaN                     No
# 3746                           NaN              Un sueldo
# 3747                           NaN  De uno a tres sueldos
#
#                salary_bonus_tied_to  \
# 0                    No recibo bono
# 1                    No recibo bono
# 2        Performance de la compañía
# 3                    No recibo bono
# 4             Mix de las anteriores
# ...                             ...
# 3743         Performance individual
# 3744                 No recibo bono
# 3745                 No recibo bono
# 3746          Mix de las anteriores
# 3747  Votado por decisión colectiva
#
#      salary_inflation_adjustment_from_last_semester  ...  \
# 0                                               Uno  ...
# 1                                               Uno  ...
# 2                                                No  ...
# 3                                                No  ...
# 4                                                No  ...
# ...                                             ...  ...
# 3743                                            Uno  ...
# 3744                                            Uno  ...
# 3745                                            Dos  ...
# 3746                                           Tres  ...
# 3747                                            Uno  ...
#
#       flow_flow_continue_oncall_1 work_on_call_duty  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3               Terminar encuesta                No
# 4                             NaN               NaN
# ...                           ...               ...
# 3743                          NaN               NaN
# 3744                          NaN               NaN
# 3745                          NaN               NaN
# 3746                          NaN               NaN
# 3747            Terminar encuesta               NaN
#
#       salary_on_call_duty_charge salary_on_call_duty_charge_notes  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            0.0                             Neto
# 4                            NaN                              NaN
# ...                          ...                              ...
# 3743                         NaN                              NaN
# 3744                         NaN                              NaN
# 3745                         NaN                              NaN
# 3746                         NaN                              NaN
# 3747                         NaN                              NaN
#
#       profile_age profile_gender profile_answered_previous_editions  \
# 0              43      Mujer Cis                                 No
# 1              59      Mujer Cis                                 Sí
# 2              39     Hombre Cis                                 Sí
# 3              37     Hombre Cis                                 Sí
# 4              35     Hombre Cis                                 Sí
# ...           ...            ...                                ...
# 3743           27     Hombre Cis                                 No
# 3744           25     Hombre Cis                                 Sí
# 3745           43     Hombre Cis                                 Sí
# 3746           24     Hombre Cis                                 Sí
# 3747           33     Hombre Cis                                 No
#
#      salary_salary_dollarized  work_seniority  salary_salary_target
# 0                        True     Semi-Senior            2511178.00
# 1                        True          Senior            2140000.00
# 2                        True     Semi-Senior            3000000.00
# 3                        True          Senior            4000000.00
# 4                        True          Senior            1300000.00
# ...                       ...             ...                   ...
# 3743                    False          Senior            4500000.00
# 3744                    False     Semi-Senior            1400000.00
# 3745                    False          Senior            3700000.00
# 3746                    False     Semi-Senior            3200000.00
# 3747                    False     Semi-Senior            1310771.18
#
# [3748 rows x 56 columns]

# %%
url = 'https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/refs/heads/master/sysarmy_survey_2025_processed.csv'
df2 = pd.read_csv(url)

# %%
df2
# Out:
#       Unnamed: 0                    work_province work_dedication  \
# 0              0  Ciudad Autónoma de Buenos Aires       Part-Time
# 1              1  Ciudad Autónoma de Buenos Aires       Full-Time
# 2              2                          Córdoba       Full-Time
# 3              3  Ciudad Autónoma de Buenos Aires       Part-Time
# 4              4                          Córdoba       Full-Time
# ...          ...                              ...             ...
# 5191        5320  Ciudad Autónoma de Buenos Aires       Part-Time
# 5192        5321  Ciudad Autónoma de Buenos Aires       Full-Time
# 5193        5322                            Salta       Full-Time
# 5194        5323                 Tierra del Fuego       Full-Time
# 5195        5324  Ciudad Autónoma de Buenos Aires       Full-Time
#
#                                      work_contract_type  salary_monthly_BRUTO  \
# 0                             Staff (planta permanente)             6500000.0
# 1                                            Contractor            12700000.0
# 2                             Staff (planta permanente)             3952805.0
# 3                             Staff (planta permanente)             1606000.0
# 4     Tercerizado (trabajo a través de consultora o ...             1325301.0
# ...                                                 ...                   ...
# 5191                          Staff (planta permanente)             2200000.0
# 5192  Tercerizado (trabajo a través de consultora o ...             1600000.0
# 5193                                         Contractor             3000000.0
# 5194                          Staff (planta permanente)             5000000.0
# 5195                          Staff (planta permanente)             2450000.0
#
#       salary_monthly_NETO                       salary_in_usd  \
# 0               5800000.0  Cobro parte del salario en dólares
# 1              10200000.0    Cobro todo el salario en dólares
# 2               3137662.0  Cobro parte del salario en dólares
# 3               1360000.0  Cobro parte del salario en dólares
# 4                     NaN  Cobro parte del salario en dólares
# ...                   ...                                 ...
# 5191            1800000.0                                 NaN
# 5192            1300000.0                                 NaN
# 5193            2400000.0                                 NaN
# 5194            4200000.0                                 NaN
# 5195            2040000.0                                 NaN
#
#      salary_last_dollar_value       salary_has_bonus  \
# 0                         NaN  De uno a tres sueldos
# 1                         NaN              Un sueldo
# 2                         985                     No
# 3                        1004                     No
# 4                         NaN                     No
# ...                       ...                    ...
# 5191                      NaN  De uno a tres sueldos
# 5192                      NaN                     No
# 5193                      NaN     Menos de un sueldo
# 5194                      NaN     Menos de un sueldo
# 5195                      NaN              Un sueldo
#
#                salary_bonus_tied_to  ...  \
# 0        Performance de la compañía  ...
# 1        Performance de la compañía  ...
# 2                    No recibo bono  ...
# 3                    No recibo bono  ...
# 4                    No recibo bono  ...
# ...                             ...  ...
# 5191          Mix de las anteriores  ...
# 5192                 No recibo bono  ...
# 5193          Mix de las anteriores  ...
# 5194  Votado por decisión colectiva  ...
# 5195         Performance individual  ...
#
#      salir_o_seguir_contestando_sobre_las_guardias  work_on_call_duty  \
# 0                                              NaN                NaN
# 1                                Terminar encuesta                 No
# 2                                              NaN                NaN
# 3                                              NaN                NaN
# 4                                Terminar encuesta                NaN
# ...                                            ...                ...
# 5191                             Terminar encuesta                NaN
# 5192                      Responder sobre guardias                 No
# 5193                                           NaN                NaN
# 5194                                           NaN                NaN
# 5195                                           NaN                NaN
#
#      salary_on_call_duty_charge  \
# 0                           NaN
# 1                           0.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 5191                        NaN
# 5192                        0.0
# 5193                        NaN
# 5194                        NaN
# 5195                        NaN
#
#       aclara_el_numero_que_ingresaste_en_el_campo_anterior profile_age  \
# 0                                                   NaN             45
# 1                                                 Bruto             32
# 2                                                   NaN             29
# 3                                                   NaN             25
# 4                                                   NaN             22
# ...                                                 ...            ...
# 5191                                                NaN             50
# 5192                      Porcentaje de mi sueldo bruto             23
# 5193                                                NaN             28
# 5194                                                NaN             58
# 5195                                                NaN             34
#
#       profile_gender  \
# 0         Hombre Cis
# 1          Mujer Cis
# 2         Hombre Cis
# 3         Hombre Cis
# 4         Hombre Cis
# ...              ...
# 5191      Hombre Cis
# 5192      Hombre Cis
# 5193      Hombre Cis
# 5194      Hombre Cis
# 5195      Hombre Cis
#
#      habias_respondido_nuestra_encuesta_en_ediciones_anteriores  \
# 0                                                    Sí
# 1                                                    Sí
# 2                                                    Sí
# 3                                                    Sí
# 4                                                    Sí
# ...                                                 ...
# 5191                                                 Sí
# 5192                                                 Sí
# 5193                                                 Sí
# 5194                                                 No
# 5195                                                 Sí
#
#      sueldo_dolarizado    seniority        _sal
# 0                 True       Senior   6500000.0
# 1                 True       Senior  12700000.0
# 2                 True  Semi-Senior   3952805.0
# 3                 True  Semi-Senior   1606000.0
# 4                 True       Senior   1325301.0
# ...                ...          ...         ...
# 5191             False       Senior   2200000.0
# 5192             False       Junior   1600000.0
# 5193             False  Semi-Senior   3000000.0
# 5194             False       Senior   5000000.0
# 5195             False       Senior   2450000.0
#
# [5196 rows x 51 columns]
